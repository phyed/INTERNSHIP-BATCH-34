# %% [markdown]
# # Q7

# %%
# necessary libraries installation & import
! pip install selenium 
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

import re
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# FIRST STEP, BROWSER CONNECTING TO THE DRIVER 
driver=webdriver.Chrome(r'C:\Users\phyed\Desktop\FLIP ROBO ASSIGNMENT\chromedriver_win32\chromedriver.exe')

# %%
driver.get('https://www.digit.in/')  # digit.in website openeed in automated chrome browser

# %%
url="https://www.digit.in/top-products/best-gaming-laptops-40.html"

# %%
driver.get(url)

# %%
# creating empty list & then scrapping details
gaming_laptop=[]
laptop_tags=driver.find_elements(By.XPATH,'//div[@class="left_side"]')
for i in laptop_tags[0:10]:
    gaming_laptop.append(str(i.text).replace('\n',' '))
gaming_laptop

specification=[]
specification_tags=driver.find_elements(By.XPATH,'//div[@class="Spcs-details"]')
for i in specification_tags:
    specification.append(str(i.text).replace('\n',' '))
specification

price=[]
price_tags=driver.find_elements(By.XPATH,"//td[@class='smprice']")
for i in price_tags:
    price.append(str(i.text).replace('\n',' '))

prod_des=[]
des_tags=driver.find_elements(By.XPATH,'//div[@class="Section-center"]')
for i in des_tags[0:10]:
    prod_des.append(str(i.text).replace('\n',' '))

dflp=pd.DataFrame({'BRAND':gaming_laptop,'PRICE':price,'PRODUCT DESCRIPTION':prod_des,'SPECIFICATIONS':specification})
dflp    # df representation
# Out:
#                                               BRAND      PRICE  \
# 0                           1. MSI Titan GT77-12UHS        N/A
# 1                               2. Alienware X17 R2  ₹ 389,990
# 2          3. Acer Predator Triton 500 SE PT516-52s  ₹ 229,990
# 3                        4. Omen By HP (16-B1371TX)  ₹ 176,490
# 4              5. Acer Predator Helios 300 AN515-45  ₹ 172,999
# 5                     6. MSI Delta 15 (A5EFK-083IN)  ₹ 188,990
# 6                        7. Omen By HP (16-C0141AX)  ₹ 124,990
# 7              8. Lenovo Legion 5i Pro (82RF00MGIN)  ₹ 169,990
# 8  9. Alienware M15 R5 Ryzen Edition Icc-C780001win  ₹ 174,000
# 9              10. Lenovo Slim 7 Gen 6 (82K8002JIN)  ₹ 131,990
#
#                                  PRODUCT DESCRIPTION  \
# 0  The very best MSI gaming laptop featuring an I...
# 1  Alienware, the premium gaming brand from Dell ...
# 2  The Predator lineup from Acer has shown great ...
# 3                        AVAILABLE ₹ 102,990 BUY NOW
# ...

# %% [markdown]
# # Q8

# %%
# FIRST STEP, BROWSER CONNECTING TO THE DRIVER 
driver=webdriver.Chrome(r'C:\Users\phyed\Desktop\FLIP ROBO ASSIGNMENT\chromedriver_win32\chromedriver.exe')

# %%
driver.get('https://www.forbes.com/lists/indonesia-billionaires/?sh=5bd1d8b52ff7')

# %%
name=[]
rank=[]
net_worth=[]
industry=[]

for i in driver.find_elements(By.XPATH,'//div[@class="personName second table-cell  name"]'):
    name.append(i.text)

for i in driver.find_elements(By.XPATH,'//div[@class="rank first table-cell  rank"]'):
    rank.append(i.text)
    
for i in driver.find_elements(By.XPATH,'//div[@class="finalWorth  table-cell  net worth "]'):
    net_worth.append(i.text)
    
for i in driver.find_elements(By.XPATH,'//div[@class="category  table-cell  industry"]'):
    industry.append(i.text)
    
import pandas as pd
df_mln=pd.DataFrame({'NAME':name,'RANK':rank,'NET WORTH':net_worth,'INDUSTRY':industry})


df_mln
# Out:
#                                          NAME RANK NET WORTH  \
# 0                   R. Budi & Michael Hartono   1.   $47.7 B
# 1                              Low Tuck Kwong   2.   $12.1 B
# 2                              Widjaja family   3.   $10.8 B
# 3                           Sri Prakash Lohia   4.    $7.7 B
# 4                      Anthoni Salim & family   5.    $7.5 B
# 5                             Chairul Tanjung   6.    $5.2 B
# 6                            Prajogo Pangestu   7.    $5.1 B
# 7                 Boenjamin Setiawan & family   8.    $4.8 B
# 8                              Tahir & family   9.    $4.2 B
# 9                               Djoko Susanto  10.    $4.1 B
# 10                    Bachtiar Karim & family  11.      $4 B
# 11               Jogi Hendra Atmadja & family  12.   $3.95 B
# 12          Wijono & Hermanto Tanoko & family  13.   $3.65 B
# 13                Susilo Wonowidjojo & family  14.    $3.5 B
# ...

# %% [markdown]
# # Q(9)

# %%
# FIRST STEP, BROWSER CONNECTING TO THE DRIVER 
driver=webdriver.Chrome(r'C:\Users\phyed\Desktop\FLIP ROBO ASSIGNMENT\chromedriver_win32\chromedriver.exe')

# %%
driver.get('https://www.youtube.com/watch?v=F2yQ17Q22s0')

# %%
comments=[]
for i in driver.find_elements(By.XPATH,'//span[@class="style-scope yt-formatted-string"]'):
    comments.append(i.text)
    
comments

upvotes=[]
for i in driver.find_elements(By.XPATH,'//span[@class="style-scope ytd-comment-action-buttons-renderer"]'):
    upvotes.append(i.text)
    
upvotes

time=[]
for i in driver.find_elements(By.XPATH,'//a[@class="yt-simple-endpoint style-scope yt-formatted-string"]'):
    time.append(i.text)

print('COMMENTS',comments)
print('-------------------------------------------------------------------------------------------------------')
print('UPVOTES',upvotes)
print("--------------------------------------------------------------------------------------------------------")
print('TIME',time)
# Out:
# COMMENTS ['', '', '', '', '', '', '', ' ', ' ', ' ', ' ', ' ', '', '', '', '', '', '', '', '2,523', 'Comments', '75% should be removed for droppers atleast ', '..... ', '', 'Thank u sir for supporting us', '', 'Teachers like you are not less than God for us in this situation', '', 'U can understand the pain of every droper', 'I am a neet aspirant but feeling so bad for all jee aspirants..!!', '', 'Because 12th board percentage can not decide our future..', '', 'Alakh sir is a pure gem ', '', 'Thank you sir for supporting all the aspirants..', 'Most point to point topic raised...', '', '', 'Proud to be an PWian', 'Thank you alakh sir ', ' for stand with us in this movement ', '', '', '', '', '', '', '', '', "I m in 11th right now and i think the system should be like   75% criteria for this year's students and NO 75% criteria for Droppers.... I am stunned after hearing what NTA is doing.... and also worried  what they are gonna do next. ", " let's hope for the best", 'Alakh sir has ga
# ...

# %% [markdown]
# # Q4

# %%
# FIRST STEP, BROWSER CONNECTING TO THE DRIVER 
driver=webdriver.Chrome(r'C:\Users\phyed\Desktop\FLIP ROBO ASSIGNMENT\chromedriver_win32\chromedriver.exe')

url4="https://www.flipkart.com/search?q=smartphone&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off"
driver.get(url4)

# %%
# creating empty lists--
Brand_Name=[]
Colour=[]
Storage_RAM_ROM=[]
P_F_Camera=[]
Display_size_Resolution=[]
ProcessorAndCores=[]
Battery=[]
Price=[]
Product_URL=[]

# %%
#scraping the Brand_Name 
BName=driver.find_elements (By.XPATH,"//div[@class='_4rR01T']")
for i in BName:
    if i.text is None :
        Brand_Name.append("--") 
    else:
        Brand_Name.append(i.text)
print(len(Brand_Name),Brand_Name)
# Out:
# 24 ['POCO C31 (Royal Blue, 64 GB)', 'POCO C31 (Shadow Gray, 64 GB)', 'REDMI 9i Sport (Metallic Blue, 64 GB)', 'REDMI 9i Sport (Coral Green, 64 GB)', 'realme C30 (Lake Blue, 32 GB)', 'realme C30 (Bamboo Green, 32 GB)', 'realme C30 (Denim Black, 32 GB)', 'REDMI 10 (Caribbean Green, 64 GB)', 'POCO M4 Pro (Cool Blue, 64 GB)', 'POCO M4 Pro (Power Black, 128 GB)', 'realme C30 (Denim Black, 32 GB)', 'realme C30 (Bamboo Green, 32 GB)', 'realme C30 (Lake Blue, 32 GB)', 'POCO M4 Pro (Yellow, 128 GB)', 'REDMI 10 (Pacific Blue, 64 GB)', 'REDMI 9i Sport (Carbon Black, 64 GB)', 'MOTOROLA e40 (Pink Clay, 64 GB)', 'POCO M4 Pro (Power Black, 64 GB)', 'POCO C31 (Royal Blue, 32 GB)', 'SAMSUNG Galaxy F13 (Sunrise Copper, 64 GB)', 'MOTOROLA g52 (Charcoal Grey, 128 GB)', 'REDMI 10 (Midnight Black, 64 GB)', 'realme 9i (Prism Black, 128 GB)', 'realme 9i (Prism Blue, 128 GB)']

# %%
#scraping the Storage_RAM_ROM 
ram=driver.find_elements(By.XPATH,"//ul[@class='_1xgFaf']//li[1]")
for i in ram:
    if i.text is None :
        Storage_RAM_ROM.append("--") 
    else:
        Storage_RAM_ROM.append(i.text)
print(len(Storage_RAM_ROM),Storage_RAM_ROM)
# Out:
# 24 ['4 GB RAM | 64 GB ROM | Expandable Upto 512 GB', '4 GB RAM | 64 GB ROM | Expandable Upto 512 GB', '4 GB RAM | 64 GB ROM | Expandable Upto 512 GB', '4 GB RAM | 64 GB ROM | Expandable Upto 512 GB', '2 GB RAM | 32 GB ROM | Expandable Upto 1 TB', '2 GB RAM | 32 GB ROM | Expandable Upto 1 TB', '2 GB RAM | 32 GB ROM | Expandable Upto 1 TB', '4 GB RAM | 64 GB ROM | Expandable Upto 1 TB', '6 GB RAM | 64 GB ROM | Expandable Upto 1 TB', '6 GB RAM | 128 GB ROM | Expandable Upto 1 TB', '3 GB RAM | 32 GB ROM | Expandable Upto 1 TB', '3 GB RAM | 32 GB ROM | Expandable Upto 1 TB', '3 GB RAM | 32 GB ROM | Expandable Upto 1 TB', '6 GB RAM | 128 GB ROM | Expandable Upto 1 TB', '4 GB RAM | 64 GB ROM | Expandable Upto 1 TB', '4 GB RAM | 64 GB ROM | Expandable Upto 512 GB', '4 GB RAM | 64 GB ROM | Expandable Upto 1 TB', '6 GB RAM | 64 GB ROM | Expandable Upto 1 TB', '3 GB RAM | 32 GB ROM | Expandable Upto 512 GB', '4 GB RAM | 64 GB ROM | Expandable Upto 1 TB', '6 GB RAM | 128 GB ROM', '4 GB RAM | 64 
# ...

# %%
#scraping the P_F_Camera 
PC=driver.find_elements(By.XPATH,"//ul[@class='_1xgFaf']//li[3]")
for i in PC:
    if i.text is None :
        P_F_Camera.append("--") 
    else:
        P_F_Camera.append(i.text)
print(len(P_F_Camera),P_F_Camera)
# Out:
# 24 ['13MP + 2MP + 2MP | 5MP Front Camera', '13MP + 2MP + 2MP | 5MP Front Camera', '13MP Rear Camera | 5MP Front Camera', '13MP Rear Camera | 5MP Front Camera', '8MP Rear Camera | 5MP Front Camera', '8MP Rear Camera | 5MP Front Camera', '8MP Rear Camera | 5MP Front Camera', '50MP + 2MP | 5MP Front Camera', '64MP + 8MP + 2MP | 16MP Front Camera', '64MP + 8MP + 2MP | 16MP Front Camera', '8MP Rear Camera | 5MP Front Camera', '8MP Rear Camera | 5MP Front Camera', '8MP Rear Camera | 5MP Front Camera', '64MP + 8MP + 2MP | 16MP Front Camera', '50MP + 2MP | 5MP Front Camera', '13MP Rear Camera | 5MP Front Camera', '48MP + 2MP + 2MP | 8MP Front Camera', '64MP + 8MP + 2MP | 16MP Front Camera', '13MP + 2MP + 2MP | 5MP Front Camera', '50MP + 5MP + 2MP | 8MP Front Camera', '50MP + 8MP + 2MP | 16MP Front Camera', '50MP + 2MP | 5MP Front Camera', '50MP + 2MP + 2MP | 16MP Front Camera', '50MP + 2MP + 2MP | 16MP Front Camera']

# %%
#scraping the Display_size_Resolution 
DS=driver.find_elements(By.XPATH,"//ul[@class='_1xgFaf']//li[2]")
for i in DS:
    if i.text is None :
        Display_size_Resolution.append("--") 
    else:
        Display_size_Resolution.append(i.text)
print(len(Display_size_Resolution),Display_size_Resolution)
# Out:
# 24 ['16.59 cm (6.53 inch) HD+ Display', '16.59 cm (6.53 inch) HD+ Display', '16.59 cm (6.53 inch) HD+ Display', '16.59 cm (6.53 inch) HD+ Display', '16.51 cm (6.5 inch) HD+ Display', '16.51 cm (6.5 inch) HD+ Display', '16.51 cm (6.5 inch) HD+ Display', '17.02 cm (6.7 inch) HD+ Display', '16.33 cm (6.43 inch) Full HD+ AMOLED Display', '16.33 cm (6.43 inch) Full HD+ AMOLED Display', '16.51 cm (6.5 inch) HD+ Display', '16.51 cm (6.5 inch) HD+ Display', '16.51 cm (6.5 inch) HD+ Display', '16.33 cm (6.43 inch) Full HD+ AMOLED Display', '17.02 cm (6.7 inch) HD+ Display', '16.59 cm (6.53 inch) HD+ Display', '16.51 cm (6.5 inch) HD+ Display', '16.33 cm (6.43 inch) Full HD+ AMOLED Display', '16.59 cm (6.53 inch) HD+ Display', '16.76 cm (6.6 inch) Full HD+ Display', '16.76 cm (6.6 inch) Full HD+ Display', '17.02 cm (6.7 inch) HD+ Display', '16.76 cm (6.6 inch) Full HD+ Display', '16.76 cm (6.6 inch) Full HD+ Display']

# %%
#scraping the ProcessorAndCores 
P=driver.find_elements(By.XPATH,"//ul[@class='_1xgFaf']//li[5]")
for i in P:
    if i.text is None :
        ProcessorAndCores.append("--") 
    else:
        ProcessorAndCores.append(i.text)
print(len(ProcessorAndCores),ProcessorAndCores)
# Out:
# 24 ['MediaTek G35 Processor', 'MediaTek Helio G35 Processor', 'MediaTek Helio G25 Processor', 'MediaTek Helio G25 Processor', 'Unisoc T612 Processor', 'Unisoc T612 Processor', 'Unisoc T612 Processor', 'Qualcomm Snapdragon 680 Processor', 'Mediatek Helio G96 Processor', 'Mediatek Helio G96 Processor', 'Unisoc T612 Processor', 'Unisoc T612 Processor', 'Unisoc T612 Processor', 'Mediatek Helio G96 Processor', 'Qualcomm Snapdragon 680 Processor', 'MediaTek Helio G25 Processor', 'UNISOC T700 Processor', 'Mediatek Helio G96 Processor', 'MediaTek Helio G35 Processor', 'Exynos 850 Processor', 'Qualcomm Snapdragon 680 Processor', 'Qualcomm Snapdragon 680 Processor', 'Qualcomm Snapdragon 680 (SM6225) Processor', 'Qualcomm Snapdragon 680 (SM6225) Processor']

# %%
#scraping the Battery 
B=driver.find_elements(By.XPATH,"//ul[@class='_1xgFaf']//li[4]")
for i in B:
    if i.text is None :
        Battery.append("--") 
    else:
        Battery.append(i.text)
print(len(Battery),Battery)
# Out:
# 24 ['5000 mAh Lithium-ion Polymer Battery', '5000 mAh Lithium-ion Polymer Battery', '5000 mAh Li-Polymer Battery', '5000 mAh Li-Polymer Battery', '5000 mAh Lithium Ion Battery', '5000 mAh Lithium Ion Battery', '5000 mAh Lithium Ion Battery', '6000 mAh Lithium Polymer Battery', '5000 mAh Lithium-ion Polymer Battery', '5000 mAh Lithium-ion Polymer Battery', '5000 mAh Lithium Ion Battery', '5000 mAh Lithium Ion Battery', '5000 mAh Lithium Ion Battery', '5000 mAh Lithium-ion Polymer Battery', '6000 mAh Lithium Polymer Battery', '5000 mAh Li-Polymer Battery', '5000 mAh Battery', '5000 mAh Lithium-ion Polymer Battery', '5000 mAh Lithium-ion Polymer Battery', '6000 mAh Lithium Ion Battery', '5000 mAh Lithium Battery', '6000 mAh Lithium Polymer Battery', '5000 mAh Lithium ion Battery', '5000 mAh Lithium ion Battery']

# %%
#scraping the Price 
price=driver.find_elements(By.XPATH,"//div[@class='_30jeq3 _1_WHN1']")
for i in price:
    if i.text is None :
        Price.append("--") 
    else:
        Price.append(i.text)
print(len(Price),Price)
# Out:
# 24 ['₹9,529', '₹9,499', '₹7,199', '₹7,199', '₹5,999', '₹5,999', '₹5,999', '₹9,499', '₹14,999', '₹16,499', '₹6,999', '₹6,999', '₹6,999', '₹16,499', '₹9,499', '₹7,199', '₹7,999', '₹14,999', '₹8,499', '₹11,999', '₹12,999', '₹9,499', '₹11,499', '₹11,499']

# %%
FlipKart=pd.DataFrame([])
FlipKart['Brand_Name']=Brand_Name
FlipKart['Storage_RAM_ROM']=Storage_RAM_ROM
FlipKart['Amount P_F_Camera']=P_F_Camera
FlipKart['Display_size_Resolution']=Display_size_Resolution
FlipKart['ProcessorAndCores']=ProcessorAndCores
FlipKart['Battery']=Battery
FlipKart['Price']=Price

FlipKart
# Out:
#                                     Brand_Name  \
# 0                 POCO C31 (Royal Blue, 64 GB)
# 1                POCO C31 (Shadow Gray, 64 GB)
# 2        REDMI 9i Sport (Metallic Blue, 64 GB)
# 3          REDMI 9i Sport (Coral Green, 64 GB)
# 4                realme C30 (Lake Blue, 32 GB)
# 5             realme C30 (Bamboo Green, 32 GB)
# 6              realme C30 (Denim Black, 32 GB)
# 7            REDMI 10 (Caribbean Green, 64 GB)
# 8               POCO M4 Pro (Cool Blue, 64 GB)
# 9            POCO M4 Pro (Power Black, 128 GB)
# 10             realme C30 (Denim Black, 32 GB)
# 11            realme C30 (Bamboo Green, 32 GB)
# 12               realme C30 (Lake Blue, 32 GB)
# 13                POCO M4 Pro (Yellow, 128 GB)
# 14              REDMI 10 (Pacific Blue, 64 GB)
# 15        REDMI 9i Sport (Carbon Black, 64 GB)
# 16             MOTOROLA e40 (Pink Clay, 64 GB)
# 17            POCO M4 Pro (Power Black, 64 GB)
# 18                POCO C31 (Royal Blue, 32 GB)
# ...

# %% [markdown]
# # Q5

# %%
# FIRST STEP, BROWSER CONNECTING TO THE DRIVER 
driver=webdriver.Chrome(r'C:\Users\phyed\Desktop\FLIP ROBO ASSIGNMENT\chromedriver_win32\chromedriver.exe')

# opening google maps
driver.get("https://www.google.co.in/maps")
time.sleep(3)

city = input('Enter City Name : ')                                         # Enter city to be searched
search = driver.find_element(By.ID,"searchboxinput")                       # locating search bar
search.clear()                                                             # clearing search bar
time.sleep(2)
search.send_keys(city)                                                     # entering values in search bar
button = driver.find_element(By.ID,"searchbox-searchbutton")               # locating search button
button.click()                                                             # clicking search button
time.sleep(3)

try:
    url_string = driver.current_url
    print("URL Extracted: ", url_string)
    lat_lng = re.findall(r'@(.*)data',url_string)
    if len(lat_lng):
        lat_lng_list = lat_lng[0].split(",")
        if len(lat_lng_list)>=2:
            lat = lat_lng_list[0]
            lng = lat_lng_list[1]
        print("Latitude = {}, Longitude = {}".format(lat, lng))

except Exception as e:
        print("Error: ", str(e))
# Out:
# Enter City Name : south dumdum
# URL Extracted:  https://www.google.co.in/maps/place/South+Dumdum,+West+Bengal/@22.605719,88.3828046,14z/data=!3m1!4b1!4m5!3m4!1s0x3a027606dc300fb1:0x1e8c3008eba56670!8m2!3d22.6089295!4d88.3983432
# Latitude = 22.605719, Longitude = 88.3828046

# %% [markdown]
# # Q10

# %%
# FIRST STEP, BROWSER CONNECTING TO THE DRIVER 
driver=webdriver.Chrome(r'C:\Users\phyed\Desktop\FLIP ROBO ASSIGNMENT\chromedriver_win32\chromedriver.exe')

# %%
driver.get('https://www.hostelworld.com/ in')

# %%
location=driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div[2]/section/div/form/div/div[1]/div/input')

# %%
location.send_keys('London')

# %%
search=driver.find_element(By.CLASS_NAME,'search-submit-row')
search.click()     #clicking on search button

# %%
hostel_name=[]
dist=[]
rating=[]
review=[]
price=[]

prop_descrip=[]

for i in driver.find_elements(By.XPATH,'//h2[@class="title title-6"]')[0:20]:
    hostel_name.append(i.text)
    
for i in driver.find_elements(By.XPATH,'//div[@class="subtitle body-3"]')[0:20]:
    dist.append(i.text)
    
for i in driver.find_elements(By.XPATH,'//div[@class="score orange big"]')[0:20]: 
    rating.append(i.text)

for i in driver.find_elements(By.XPATH,'//div[@class="keyword"]')[0:20]:
    review.append(i.text)
    
for i in driver.find_elements(By.XPATH,'//div[@class="price title-5"]')[0:20]:
    price.append(i.text)
    
for i in driver.find_elements(By.XPATH,'//div[@class="rating-factors prop-card-tablet rating-factors small"]')[0:20]:
    prop_descrip.append(i.text)
    

print(len(rating))
print(len(prop_descrip))
print(len(hostel_name))
print(len(review))
print(len(price))
print(len(dist))

df_hostel=pd.DataFrame({'Hostel Name':hostel_name,'DISTANCE':dist,'Rating':rating,'Review':review,'Price':price,'Property Description':prop_descrip})
df_hostel
# Out:
# 20
# 20
# 20
# 20
# 20
# 20
#                                 Hostel Name  \
# 0               Wombat's City Hostel London
# 1                  St Christopher's Village
# 2                   Hostel One Notting Hill
# 3                      Urbany Hostel London
# 4                          Generator London
# 5         Safestay London Elephant & Castle
# 6               Smart Russell Square Hostel
# 7                   St Christopher's Camden
# 8   Safestay London Kensington Holland Park
# 9                          NX London Hostel
# 10                  Smart Camden Inn Hostel
# 11                           Phoenix Hostel
# 12             St Christopher's Hammersmith
# 13                       London Backpackers
# 14              Smart Hyde Park View Hostel
# 15                           Astor Victoria
# 16  St Christopher's Inn - Liverpool Street
# 17                  Saint James Backpackers
# 18               St Christopher's Greenwich
# 19          St Christopher's Shepherds Bush
# ...

# %% [markdown]
# # Q6

# %%
# FIRST STEP, BROWSER CONNECTING TO THE DRIVER 
driver=webdriver.Chrome(r'C:\Users\phyed\Desktop\FLIP ROBO ASSIGNMENT\chromedriver_win32\chromedriver.exe')

# %%
url1="https://trak.in/india-startup-funding-investment-2015/"
driver.get(url1)

# %%
Dates=[]
Company=[]
Industry=[]
Investor_Name=[]
Investment_Type=[]
Amount=[]

# %%
#scraping the company_name 
companies=driver.find_elements(By.XPATH,"//td[@class='column-3']")
for i in companies:
    if i.text is None :
        Company.append("--") 
    else:
        Company.append(i.text)
print(len(Company),Company)
# Out:
# 392 ['BYJU’S', 'Meesho', 'Swiggy', 'Groww', 'Beldara', 'DealShare', 'Uniphore', 'Dunzo', 'BYJU’S', 'SkilloVilla', 'CityMall', 'DotPe', 'Doubtnut', 'Zomato', 'Fingerlix', 'Zolve', 'KreditBee', 'Pepperfry', 'Grofers', 'Nothing', 'SplashLearn', 'Digit Insurance', 'Bombay Shaving Company', 'DeHaat', 'Darwinbox', 'mfine', 'Udayy', 'True Elements', 'Saveo', 'Bira 91', 'Pine Labs', 'Zenoti', 'Tax Buddy India', 'Delhivery', 'PagarBook', 'Codingal', 'CRED', 'Bira 91', 'Chumbak', 'Cityflo', 'Shipsy', 'Unacademy', 'Cashfree', 'Credgenics', 'Country Delight', 'Nykaa', 'Betterplace', 'FlexiLoans', 'GetVantage', 'FreshToHome', 'Origo', 'Origo', 'Treebo Hotels', 'Hubilo', 'CredAble', 'Byju’s', 'mCaffeine', 'Qshala', 'Winzo', 'Hippo Video', 'Melorra', '1mg', 'mfine', 'Apna', 'Railofy', 'Practo', 'Medlife', 'HungerBox', 'Dunzo', 'Terra.do', 'Classplus', 'Niyo', 'ZestMoney', 'FreshToHome', 'Eduvanz', 'Flipkart', 'Vedantu', 'Crio', 'goDutch', 'Mystifly', 'JetSynthesys', 'gigIndia', 'PumPumPum', 'FLYX',
# ...

# %%
#scraping the Industry 
Ind=driver.find_elements(By.XPATH,"//td[@class='column-4']")
for i in Ind:
    if i.text is None :
        Industry.append("--") 
    else:
        Industry.append(i.text)
print(len(Industry),Industry)
# Out:
# 392 ['Edu-tech', 'E-commerce', 'Online Food Delivery', 'FinTech', 'E-commerce', 'E-commerce', 'Technology', 'E-commerce', 'Edu-tech', 'Edu-tech', 'E-commerce', 'FinTech', 'Edu Tech', 'Hospitality', 'Hospitality', 'FinTech', 'Finance', 'E-commerce', 'E-Commerce', 'Technology', 'EdTech', 'Financial Services', 'Consumer Goods Company', 'AgriTech Startup', 'SaaS', 'Health Tech Startup', 'EdTech', 'Food Startup', 'B2B E-commerce', 'Food and Beverage', 'Financial Services', 'Technology Provider', 'FinTech', 'Supply chain', 'SaaS', 'EduTech', 'Financial Services', 'Food and Beverage', 'Lifestyle', 'Transportation', 'SaaS', 'Edutech', 'FinTech', 'Fintech', 'Dairy Tech', 'E-commerce', 'Digital Solutions', 'FinTech', 'FinTech', 'E-commerce', 'AgriTech', 'Advertising', 'Hospitality', 'Information Technology', 'FinTech', 'EduTech', 'Personal Care', 'EduTech', 'Online Gaming', 'Video Customer Experience(CX) Platform', 'E-commerce', 'E-commerce', 'HealthTech', 'Human Resources', 'Transportation', 
# ...

# %%
#scraping the Dates 
dt=driver.find_elements(By.XPATH,"//td[@class='column-2']")
for i in dt:
    if i.text is None :
        Dates.append("--") 
    else:
        Dates.append(i.text)
print(len(Dates),Dates)
# Out:
# 392 ['01/04/2021', '05/04/2021', '14/04/2021', '07/04/2021', '14/04/2021', '04/03/2021', '31/03/2021', '30/03/2021', '30/03/2021', '23/03/2021', '25/03/2021', '26/03/2021', '11/02/2021', '22/02/2021', '19/02/2021', '17/02/2021', '15/02/2021', '12/02/2021', '12/02/2021', '09/02/2021', '09/02/2021', '15/01/2021', '28/01/2021', '19/01/2021', '19/01/2021', '18/01/2021', '18/01/2021', '11/01/2021', '13/01/2021', '15/12/2020', '21/12/2020', '15/12/2020', '22/12/2020', '15/12/2020', '18/12/2020', '30/11/2020', '30/11/2020', '29/11/2020', '27/11/2020', '25/11/2020', '25/11/2020', '25/11/2020', '24/11/2020', '30/11/2020', '23/11/2020', '28/10/2020', '28/10/2020', '28/10/2020', '27/10/2020', '27/10/2020', '27/10/2020', '27/10/2020', '15/10/2020', '26/10/2020', '28/10/2020', '08/09/2020', '12/09/2020', '09/09/2020', '02/09/2020', '09/09/2020', '07/09/2020', '07/09/2020', '31/08/2020', '31/08/2020', '03/09/2020', '15/08/2020', '13/08/2020', '13/08/2020', '04/08/2020', '11/08/2020', '12/08/2020',
# ...

# %%
#scraping the Investor_Name 
IN=driver.find_elements(By.XPATH,"//td[@class='column-7']")
for i in IN:
    if i.text is None :
        Investor_Name.append("--") 
    else:
        Investor_Name.append(i.text)
print(len(Investor_Name),Investor_Name)
# Out:
# 392 ['Innoven Capital', 'SoftBank Vision Fund 2', 'Amansa Holdings, Carmignac, Falcon Edge Capital, Goldman Sachs, Think Investments', 'MC Global Edtech, B Capital, Baron, others', 'Hindustan Media Ventures', 'Innoven Capital', 'Sorenson Capital Partners', 'Krishtal Advisors Pte Ltd', 'MC Global Edtech, B Capital, Baron, others', 'Titan Capital, others', 'Accel Partners', 'PayU', 'SIG Global, Sequoia Capital, WaterBridge Ventures and ON Mauritius', 'Tiger Global, Kora', 'Rhodium Trust, Accel Partners and Swiggy', 'Accel Partners and Lightspeed Venture Partners', 'Azim Premji’s PremjiInvest and South Korea’s Mirae Asset Venture', 'InnoVen Capital', 'SoftBank Vision Fund (SVF)', 'GV', 'Owl Ventures', 'A91 Partners, Faering Capital, TVS Capital Funds', 'Reckitt Benckiser', 'Prosus Ventures', 'Salesforce Ventures', 'Heritas Capital Management', 'Sequoia Capital', 'SIDBI Venture Capital', 'Matrix Partners India, RTP Global, others', 'Nishant Mittal, Pankaj Chaddah and Shikha Sunil Chandak
# ...

# %%
#scraping the Investment_Type 
IT=driver.find_elements(By.XPATH,"//td[@class='column-8']")
for i in IT:
    if i.text is None :
        Investment_Type.append("--") 
    else:
        Investment_Type.append(i.text)
print(len(Investment_Type),Investment_Type)
# Out:
# 392 ['Series F', 'Series E', 'Series J', 'Series D', 'Venture', 'Debt Financing', 'Series D', 'Series E', 'Series F', 'Seed', 'Series A', 'Series A', 'Series B', 'Venture', 'Series C', 'Seed', 'Series C', 'Debt Financing', 'Unspecified', 'Series A', 'Series C', 'Venture', 'Venture', 'Series C', 'Seed', 'Venture Round', 'Seed Funding', 'Series', 'Seed', 'Funding', 'Secondary Market', 'Series D', 'Seed', 'Secondary Market', 'Series A', 'Seed', 'Series C', 'Bridge Funding', 'Pre-series E', 'Series A', 'Series A', 'Venture', 'Series B', 'Pre-Series A', 'Series C', 'Personal Investment', 'Series B', 'Equity and Debt', 'Seed', 'Series C', 'Debt', 'Series A', '', 'Seed', 'Follow-On', 'Private Equity', 'Series B', 'Angel', 'Series B', 'Series A', 'Debt Financing', 'In Progress', 'Series B', 'Series A', 'Seed', 'Series F', '', 'Series D1', 'In Progress', 'Seed', 'In Progress', '', '', 'Venture', 'Series A', 'M&A', 'Series D', 'pre-Series A', 'Seed', 'pre-Series B', 'Venture-Series Unknown', '
# ...

# %%
#scraping the Amount 
Price=driver.find_elements(By.XPATH,"//td[@class='column-9']")
for i in Price:
    if i.text is None :
        Amount.append("--") 
    else:
        Amount.append(i.text)
print(len(Amount),Amount)
# Out:
# 392 ['460,000,000', '300,000,000', '343,000,000', '83,000,000', '7,400,000', '250,000,000', '140,000,000', '8,000,000', '460,000,000', '300,000,000', '11,000,000', '27,500,000', '2,500,000', '250,000,000', '2,747,045.20', '1,50,00,000', '75,000,000', '4,773,958', '55,000,000', '15,000,000', '18,000,000', '1,80,00,000', '6,172,258.50', '30,000,000', '15,000,000', '16,000,000', '15,000,000', '100,000,000', '4,000,000', '1,273,634.07', 'Undisclosed', '160,000,000', '1,000,000', '25,000,000', '15,000,000', '560,000', '80,000,000', '3,000,000', '1,001,047.92', '7,700,000', '6,003,806', '75,000,000-100,000,000', '35,300,000', '3,500,000', '25,000,000', 'NA', '10,000,000', '20,160,000', '5,000,000', '121,000,000', '4,700,000', '15,000,000', '6,000,000', '4,500,000', '4,500,000', '500,000,000', '3,000,000', '370,000', '15,500,000', '4,500,000', 'upto 8,900,000', '100,000,000', '5,400,000', '8,000,000', '950,000', '32,000,000', '23,000,000', '1,560,000', '30,000,000', '1,400,000', 'upto 15,00
# ...

# %%
Funding=pd.DataFrame([])
Funding['Company']=Company
Funding['Industry']=Industry
Funding['Investor_Name']=Investor_Name
Funding['Amount Invested']=Amount
Funding['Specification']=Investment_Type
Funding['Dates']=Dates
Funding
# Out:
#             Company              Industry  \
# 0            BYJU’S              Edu-tech
# 1            Meesho            E-commerce
# 2            Swiggy  Online Food Delivery
# 3             Groww               FinTech
# 4           Beldara            E-commerce
# ..              ...                   ...
# 387        zippserv     Consumer Internet
# 388           Groww     Consumer Internet
# 389   Avenue Growth     Consumer Internet
# 390           iNICU            Healthcare
# 391  Kinara Capital               Finance
#
#                                          Investor_Name Amount Invested  \
# 0                                      Innoven Capital     460,000,000
# 1                               SoftBank Vision Fund 2     300,000,000
# 2    Amansa Holdings, Carmignac, Falcon Edge Capita...     343,000,000
# 3           MC Global Edtech, B Capital, Baron, others      83,000,000
# 4                             Hindustan Media Ventures       7,400,000
# ...

# %% [markdown]
# # Q1 & 2(DID ONE PAGE SCRAPPING DUE TO TIME ISSUE BUT I CAN SOLVE FOR MULTI-PAGES AS WELL)

# %%
# FIRST STEP, BROWSER CONNECTING TO THE DRIVER 
driver=webdriver.Chrome(r'C:\Users\phyed\Desktop\FLIP ROBO ASSIGNMENT\chromedriver_win32\chromedriver.exe')

driver.get('https://www.amazon.in/')

# %%
inputU = input('please enter product here--->')
# Out:
# please enter product here--->guitar

# %%
product = driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input')    
product.send_keys(inputU)       # Inputing keyword to search 

search_button = driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input')    
search_button.click()        # Clicking the search button

# FIRST I TRIED WITH CLASS NAME,NOT WORKING....THEN TRIED WITH X PATH & WORKING,THANKS...

# %%
# empty list & scrapping prod_name
productName=[]
PName=driver.find_elements(By.XPATH,'//h2[@class="a-size-mini a-spacing-none a-color-base s-line-clamp-4"]')
for i in PName[0:30]:
    if i.text is None :
        productName.append("--") 
    else:
        productName.append(i.text)
print(len(productName),productName)
# Out:
# 30 ['Kadence Frontier guitar with Online Guitar learning course , Wine Red Acoustic Guitar with Die Cast Keys, Set of Strings, Strap, Picks and Bag (Wine Red, Acoustic)', 'Kadence Slowhand Premium Jumbo Semi Acoustic Guitar with Heavy Padded Bag, guitar cable, Pro Capo (Black Spruce Wood)', 'INTERN 40 inches Acoustic Guitar with Pick-up & truss rod, carry bag, strings pack, strap & picks. Premium Wooden durable built, tonal stability with professional sound amplificaiton. (Black).', "Gibz's G-38 Matte Acoustic Guitar With Truss Rod - Black", 'Juârez Acoustic Guitar, 38 Inch Cutaway, 038C with Bag, Strings, Pick and Strap, Black', 'INTERN 40 inches Acoustic Guitar with Pick-up & truss rod, carry bag, strings pack, strap & picks. Premium Wooden durable built, tonal stability with professional sound amplificaiton. (Black).', 'Yamaha F280 Acoustic Rosewood Guitar (Natural, Beige)', 'Intern INT-38C Acoustic Guitar Kit (Blue)', 'Juarez Lindenwood Acoustic Guitar, 38 Inches Curved Body Cuta
# ...

# %%
# scrapping price 
price=[]
for i in driver.find_elements(By.XPATH,'//span[@class="a-price-whole"]')[0:30]:
    price.append(i.text)
price
# Out:
# ['7,049',
#  '4,949',
#  '9,900',
#  '5,189',
#  '4,498',
#  '2,149',
#  '5,189',
#  '7,490',
#  '6,998',
#  '2,399',
#  '2,440',
#  '2,099',
#  '2,759',
#  '9,990',
#  '5,498',
#  '4,949',
#  '5,397',
#  '2,299',
#  '2,099',
#  '4,480',
#  '2,755',
#  '2,199',
#  '368',
#  '4,464',
#  '10,800',
#  '4,199',
#  '9,900',
#  '2,749',
#  '3,522',
#  '6,990']

# %%
# scrapping expected delivary
expdel=[]
for i in driver.find_elements(By.XPATH,'//span[@class="a-color-base"]')[0:30]:
    expdel.append(i.text)
expdel
# Out:
# ['',
#  'Get it by',
#  'FREE Delivery by Amazon',
#  '',
#  'Get it by',
#  'FREE Delivery by Amazon',
#  '',
#  'Get it by',
#  'FREE Delivery by Amazon',
#  '',
#  'Get it by',
#  'FREE Delivery by Amazon',
#  'Get it by',
#  'FREE Delivery by Amazon',
#  'Get it by',
#  'FREE Delivery by Amazon',
#  'Get it by',
#  'FREE Delivery by Amazon',
#  '₹7,348',
#  'Get it by',
#  'FREE Delivery by Amazon',
#  'Get it by',
#  'FREE Delivery by Amazon',
#  'Get it by',
#  'FREE Delivery by Amazon',
#  'Get it by',
#  'FREE Delivery by Amazon',
#  'Get it by',
#  'FREE Delivery by Amazon',
#  'Get it by']

# %%
len(expdel)
# Out:
# 30

# %%
len(price)
# Out:
# 30

# %%
len(productName)
# Out:
# 30

# %%
df_guitar=pd.DataFrame({'Product Name':productName,'Price':price,'Expected Delivary':expdel})
df_guitar
# Out:
#                                          Product Name   Price  \
# 0   Kadence Frontier guitar with Online Guitar lea...   7,049
# 1   Kadence Slowhand Premium Jumbo Semi Acoustic G...   4,949
# 2   INTERN 40 inches Acoustic Guitar with Pick-up ...   9,900
# 3   Gibz's G-38 Matte Acoustic Guitar With Truss R...   5,189
# 4   Juârez Acoustic Guitar, 38 Inch Cutaway, 038C ...   4,498
# 5   INTERN 40 inches Acoustic Guitar with Pick-up ...   2,149
# 6   Yamaha F280 Acoustic Rosewood Guitar (Natural,...   5,189
# 7           Intern INT-38C Acoustic Guitar Kit (Blue)   7,490
# 8   Juarez Lindenwood Acoustic Guitar, 38 Inches C...   6,998
# 9   Intern 38C Ebony Wood Cutaway Design Acoustic ...   2,399
# 10  JUAREZ JRZ38C 38 Inches Lindenwood Right Hande...   2,440
# 11               Yamaha FS100C Acoustic Guitar, Black   2,099
# 12  Kadence rosewood Guitar Frontier Series, Elect...   2,759
# 13  Kadence Frontier guitar with Online Guitar lea...   9,990
# ...

# %%
#scrapping url---

url_p=driver.find_elements(By.XPATH,'//a[@class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"]')
for i in url_p[0:30]:
    print(i.get_attribute('href'))
# Out:
# https://www.amazon.in/sspa/click?ie=UTF8&spc=MTo2ODU2MDYyMTY3MzU3NjIxOjE2NzE4MTE4MTA6c3BfYXRmOjIwMDYxNjIwNjk2MjA0OjowOjo&url=%2FKadence-Frontier-Acoustic-Guitar-Strings%2Fdp%2FB01GDZ46AA%2Fref%3Dsr_1_1_sspa%3Fcrid%3D2EIE6Z2DOUAE3%26keywords%3Dguitar%2Bguitar%26qid%3D1671811810%26sprefix%3Dguitar%252Caps%252C549%26sr%3D8-1-spons%26sp_csd%3Dd2lkZ2V0TmFtZT1zcF9hdGY%26psc%3D1%26smid%3DAM04Z7MH4HSDD
# https://www.amazon.in/sspa/click?ie=UTF8&spc=MTo2ODU2MDYyMTY3MzU3NjIxOjE2NzE4MTE4MTA6c3BfYXRmOjIwMDU3MTkzMDU2MjA0OjowOjo&url=%2FKadence-Slowhand-Premium-Acoustic-Instrument%2Fdp%2FB077SZ667X%2Fref%3Dsr_1_2_sspa%3Fcrid%3D2EIE6Z2DOUAE3%26keywords%3Dguitar%2Bguitar%26qid%3D1671811810%26sprefix%3Dguitar%252Caps%252C549%26sr%3D8-2-spons%26sp_csd%3Dd2lkZ2V0TmFtZT1zcF9hdGY%26psc%3D1
# ...

# %%
len(url_p)
# Out:
# 66

# %%
df=pd.DataFrame(url_p)

# %%
df_url=df.head(30)
df_url
# Out:
#                                                     0
# 0   <selenium.webdriver.remote.webelement.WebEleme...
# 1   <selenium.webdriver.remote.webelement.WebEleme...
# 2   <selenium.webdriver.remote.webelement.WebEleme...
# 3   <selenium.webdriver.remote.webelement.WebEleme...
# 4   <selenium.webdriver.remote.webelement.WebEleme...
# 5   <selenium.webdriver.remote.webelement.WebEleme...
# 6   <selenium.webdriver.remote.webelement.WebEleme...
# 7   <selenium.webdriver.remote.webelement.WebEleme...
# 8   <selenium.webdriver.remote.webelement.WebEleme...
# 9   <selenium.webdriver.remote.webelement.WebEleme...
# 10  <selenium.webdriver.remote.webelement.WebEleme...
# 11  <selenium.webdriver.remote.webelement.WebEleme...
# 12  <selenium.webdriver.remote.webelement.WebEleme...
# 13  <selenium.webdriver.remote.webelement.WebEleme...
# 14  <selenium.webdriver.remote.webelement.WebEleme...
# 15  <selenium.webdriver.remote.webelement.WebEleme...
# ...

# %%
import pandas as pd
df_finalQ2=pd.concat([df_guitar,df_url],ignore_index=True,axis=1)
df_finalQ2

# rename columns
df_finalQ2_col_name = df_finalQ2.rename(columns={0: 'BrandName', 1: 'Price', 2: 'EXp Delivary',3:'url'})
df_finalQ2_col_name
# Out:
#                                             BrandName   Price  \
# 0   Kadence Frontier guitar with Online Guitar lea...   7,049
# 1   Kadence Slowhand Premium Jumbo Semi Acoustic G...   4,949
# 2   INTERN 40 inches Acoustic Guitar with Pick-up ...   9,900
# 3   Gibz's G-38 Matte Acoustic Guitar With Truss R...   5,189
# 4   Juârez Acoustic Guitar, 38 Inch Cutaway, 038C ...   4,498
# 5   INTERN 40 inches Acoustic Guitar with Pick-up ...   2,149
# 6   Yamaha F280 Acoustic Rosewood Guitar (Natural,...   5,189
# 7           Intern INT-38C Acoustic Guitar Kit (Blue)   7,490
# 8   Juarez Lindenwood Acoustic Guitar, 38 Inches C...   6,998
# 9   Intern 38C Ebony Wood Cutaway Design Acoustic ...   2,399
# 10  JUAREZ JRZ38C 38 Inches Lindenwood Right Hande...   2,440
# 11               Yamaha FS100C Acoustic Guitar, Black   2,099
# 12  Kadence rosewood Guitar Frontier Series, Elect...   2,759
# 13  Kadence Frontier guitar with Online Guitar lea...   9,990
# ...

# %% [markdown]
# # Q3

# %%
# FIRST STEP, BROWSER CONNECTING TO THE DRIVER 
driver=webdriver.Chrome(r'C:\Users\phyed\Desktop\FLIP ROBO ASSIGNMENT\chromedriver_win32\chromedriver.exe')

# %%
driver.get('https://images.google.com/')

# %%
search_bar = driver.find_element(By.XPATH,'/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input')    # Finding the search bar using it's xpath
search_bar.send_keys("fruits")       # Inputing "banana" keyword to search rock images

search_button = driver.find_element(By.CLASS_NAME,'zgAlFc')  
search_button.click()

# %%
print("start scrolling to generate more images on the page...")
# 500 time we scroll down by 10000 in order to generate more images on the website
for _ in range(500):
    driver.execute_script("window.scrollBy(0,10000)")
# Out:
# start scrolling to generate more images on the page...

# %%
images = driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')

# %%
img_urls = []
img_data = []
for image in images:
    source= image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            img_urls.append(source)
len(img_urls)
# Out:
# 154

# %%
import requests
for i in range(len(img_urls)):
    if i >= 100:
        break
    print("Downloading {0} of {1} images" .format(i, 100))
    response= requests.get(img_urls[i])
    file = open("C:/Users/phyed/Desktop/FLIP ROBO ASSIGNMENT/img"+str(i)+".jpg", "wb") # saving the images in particular location 
    file.write(response.content)
